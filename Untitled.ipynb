# %% [markdown]
# ### Domain: Agriculture / Precision Farming
# In modern agriculture, early identification and classification of plant diseases are critical for ensuring crop health and maximizing yield. Rice, being a staple food for over half of the world's population, is especially vulnerable to various diseases that can drastically reduce productivity.
#
# Manual identification of rice diseases by farmers or agronomists is time-consuming, labor-intensive, and prone to human error. Leveraging Artificial Intelligence (AI) and Computer Vision for automating the detection of rice leaf diseases offers significant improvements in efficiency and accuracy.
#
# Use of Deep Learning in Agriculture
# Deep learning, particularly Convolutional Neural Networks (CNNs), has emerged as a powerful tool for image-based plant disease detection. CNNs are capable of automatically extracting and learning features such as color patterns, texture, and shape that differentiate healthy and diseased leaves — enabling reliable and scalable detection without hand-crafted features.
#
# Case Study: Rice Leaf Disease Detection
# #### Objective:
# To develop a deep learning model that can classify images of rice leaves into three disease categories:
#
# Leaf Smut
#
# Brown Spot
#
# Bacterial Leaf Blight
#
# #### Dataset Summary:
# Total Images: 120 JPG images
#
# Classes: 3
#
# Images per Class: 40
#
# Image Format: .jpg
#
# Data Type: RGB images
#
# 📷 Disease Classes Description:
# Leaf Smut: Characterized by black lesions and powdery spores; caused by fungus Entyloma oryzae.
#
# Brown Spot: Appears as brown circular spots; caused by Cochliobolus miyabeanus fungus.
#
# Bacterial Leaf Blight: Yellowish and wilted leaf tips; caused by Xanthomonas oryzae bacterium.

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/39.5 MB 656.4 kB/s eta 0:01:01
#    ---------------------------------------- 0.3/39.5 MB 2.3 MB/s eta 0:00:18
#    ---------------------------------------- 0.5/39.5 MB 3.0 MB/s eta 0:00:13
#     --------------------------------------- 0.5/39.5 MB 2.5 MB/s eta 0:00:16
#     --------------------------------------- 0.7/39.5 MB 2.8 MB/s eta 0:00:14
#     --------------------------------------- 0.9/39.5 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.4/39.5 MB 4.0 MB/s eta 0:00:10
#    - -------------------------------------- 1.8/39.5 MB 4.4 MB/s eta 0:00:09
#    -- ------------------------------------- 2.0/39.5 MB 4.5 MB/s eta 0:00:09
#    -- ------------------------------------- 2.4/39.5 MB 4.9 MB/s eta 0:00:08
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/49.8 kB ? eta -:--:--
#      ---------------------------------------- 49.8/49.8 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.4/376.0 MB 11.9 MB/s eta 0:00:32
#    ---------------------------------------- 0.8/376.0 MB 10.8 MB/s eta 0:00:35
#    ---------------------------------------- 1.2/376.0 MB 9.3 MB/s eta 0:00:41
#    ---------------------------------------- 1.2/376.0 MB 9.3 MB/s eta 0:00:41
#    ---------------------------------------- 1.2/376.0 MB 9.3 MB/s eta 0:00:41
#    ---------------------------------------- 1.3/376.0 MB 4.9 MB/s eta 0:01:16
#    ---------------------------------------- 1.8/376.0 MB 5.4 MB/s eta 0:01:10
#    ---------------------------------------- 2.3/376.0 MB 6.2 MB/s eta 0:01:01
#    ---------------------------------------- 3.0/376.0 MB 6.6 MB/s eta 0:00:57
# ...

# %%
pip uninstall tensorflow
pip uninstall tensorflow-estimator
# Out:
#   Cell In[7], line 1
#     pip uninstall tensorflow
#         ^
# SyntaxError: invalid syntax
